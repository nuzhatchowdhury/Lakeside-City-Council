# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
first_round = pd.read_csv("first_round_may.csv")

mail = pd.read_excel("mail_ballots.xlsx")

northgate = pd.read_csv("northgate_early_inperson.csv")

registered = pd.read_csv("registered_voters.csv")

southfield = pd.read_excel("southfield_early_inperson.xlsx")

# %%
import pandas as pd

first_round = pd.read_csv("first_round_may.csv")

# %%
first_round.head()
# Out:
#    voter_id             name          election   vote_date
# 0   7002115  Michael Johnson  2026 May General  2026-05-06
# 1   7002116     Jennifer Lee  2026 May General  2026-05-04
# 2   7006216    Yuki Martinez  2026 May General  2026-05-04
# 3   7002123        Jose Khan  2026 May General  2026-05-05
# 4   7006220   Jennifer Davis  2026 May General  2026-05-06

# %%
first_round.describe()
# Out:
#            voter_id
# count  1.169000e+03
# mean   7.004964e+06
# std    2.926318e+03
# min    7.000018e+06
# 25%    7.002405e+06
# 50%    7.004960e+06
# 75%    7.007447e+06
# max    7.009966e+06

# %%
first_round.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   voter_id   1169 non-null   int64
#  1   name       1169 non-null   object
#  2   election   1169 non-null   object
#  3   vote_date  1169 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 36.7+ KB

# %%
first_round['vote_date'] = pd.to_datetime(first_round['vote_date'])

# %%
first_round.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   voter_id   1169 non-null   int64
#  1   name       1169 non-null   object
#  2   election   1169 non-null   object
#  3   vote_date  1169 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 36.7+ KB

# %%
first_round['voter_id'] = first_round['voter_id'].astype(str)

# %%
first_round.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   voter_id   1169 non-null   object
#  1   name       1169 non-null   object
#  2   election   1169 non-null   object
#  3   vote_date  1169 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 36.7+ KB

# %%
first_round.head()
# Out:
#   voter_id             name          election  vote_date
# 0  7002115  Michael Johnson  2026 May General 2026-05-06
# 1  7002116     Jennifer Lee  2026 May General 2026-05-04
# 2  7006216    Yuki Martinez  2026 May General 2026-05-04
# 3  7002123        Jose Khan  2026 May General 2026-05-05
# 4  7006220   Jennifer Davis  2026 May General 2026-05-06

# %%
first_round['vote_date'].head()
# Out:
# 0   2026-05-06
# 1   2026-05-04
# 2   2026-05-04
# 3   2026-05-05
# 4   2026-05-06
# Name: vote_date, dtype: datetime64[ns]

# %%
first_round.duplicated().sum()
# Out:
# np.int64(0)

# %%
first_round.isnull().sum()
# Out:
# voter_id     0
# name         0
# election     0
# vote_date    0
# dtype: int64

# %%
import pandas as pd
mail = pd.read_excel("mail_ballots.xlsx")

# %%
mail.head()
# Out:
#       VUID            Voter   City State Return Date
# 0  7004160   Linda Anderson  LAKESIDE TX  2026-06-02
# 1  7004800         Liam Lee  LAKESIDE TX  2026-06-02
# 2  7007233  Elizabeth Rossi  LAKESIDE TX  2026-06-01
# 3  7007748   Emma Hernandez  LAKESIDE TX  2026-06-02
# 4  7003783        Mei Singh  LAKESIDE TX  2026-06-02

# %%
mail.describe()
# Out:
#                VUID
# count  7.400000e+01
# mean   7.004516e+06
# std    2.739010e+03
# min    7.000127e+06
# 25%    7.002249e+06
# 50%    7.004720e+06
# 75%    7.006111e+06
# max    7.009966e+06

# %%
mail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VUID         74 non-null     int64
#  1   Voter        74 non-null     object
#  2   City State   74 non-null     object
#  3   Return Date  74 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.4+ KB

# %%
mail["Return Date"] = pd.to_datetime(mail["Return Date"])

# %%
mail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VUID         74 non-null     int64
#  1   Voter        74 non-null     object
#  2   City State   74 non-null     object
#  3   Return Date  74 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 2.4+ KB

# %%
mail["VUID"] = mail["VUID"].astype(str)

# %%
mail["Voter"] = mail["Voter"].astype("string")

# %%
mail["City State"] = mail["City State"].astype("string")

# %%
mail["City State"] = mail["City State"].astype("category")

# %%
mail["Return Date"].head()
# Out:
# 0   2026-06-02
# 1   2026-06-02
# 2   2026-06-01
# 3   2026-06-02
# 4   2026-06-02
# Name: Return Date, dtype: datetime64[ns]

# %%
mail["City State"].nunique()
# Out:
# 1

# %%
mail.sort_values("Return Date")
# Out:
#        VUID           Voter   City State Return Date
# 36  7001666      John Patel  LAKESIDE TX  2026-06-01
# 45  7009110     Liam Mensah  LAKESIDE TX  2026-06-01
# 46  7002328     Linda Cohen  LAKESIDE TX  2026-06-01
# 38  7000388  Priya Anderson  LAKESIDE TX  2026-06-01
# 47  7002331       Sofia Lee  LAKESIDE TX  2026-06-01
# ..      ...             ...          ...         ...
# 37  7005635      David Wang  LAKESIDE TX  2026-06-02
# 39  7000130      Omar Smith  LAKESIDE TX  2026-06-02
# 40  7003076  Michael Garcia  LAKESIDE TX  2026-06-02
# 42  7006672      John Smith  LAKESIDE TX  2026-06-02
# 73  7005280      John Rossi  LAKESIDE TX  2026-06-02
#
# [74 rows x 4 columns]

# %%
mail[mail["Return Date"] >= "2026-06-01"]
# Out:
#        VUID            Voter   City State Return Date
# 0   7004160   Linda Anderson  LAKESIDE TX  2026-06-02
# 1   7004800         Liam Lee  LAKESIDE TX  2026-06-02
# 2   7007233  Elizabeth Rossi  LAKESIDE TX  2026-06-01
# 3   7007748   Emma Hernandez  LAKESIDE TX  2026-06-02
# 4   7003783        Mei Singh  LAKESIDE TX  2026-06-02
# ..      ...              ...          ...         ...
# 69  7000127   Jennifer Rossi  LAKESIDE TX  2026-06-01
# 70  7006100     James Nguyen  LAKESIDE TX  2026-06-01
# 71  7008479    Robert Wilson  LAKESIDE TX  2026-06-01
# 72  7002045      David Patel  LAKESIDE TX  2026-06-02
# 73  7005280       John Rossi  LAKESIDE TX  2026-06-02
#
# [74 rows x 4 columns]

# %%
mail["Return Date"].dt.month
# Out:
# 0     6
# 1     6
# 2     6
# 3     6
# 4     6
#      ..
# 69    6
# 70    6
# 71    6
# 72    6
# 73    6
# Name: Return Date, Length: 74, dtype: int32

# %%
mail["Return Date"] = pd.to_datetime(mail["Return Date"])

# %%
mail.head()
# Out:
#       VUID            Voter   City State Return Date
# 0  7004160   Linda Anderson  LAKESIDE TX  2026-06-02
# 1  7004800         Liam Lee  LAKESIDE TX  2026-06-02
# 2  7007233  Elizabeth Rossi  LAKESIDE TX  2026-06-01
# 3  7007748   Emma Hernandez  LAKESIDE TX  2026-06-02
# 4  7003783        Mei Singh  LAKESIDE TX  2026-06-02

# %%
mail.duplicated().sum()
# Out:
# np.int64(5)

# %%
mail.isnull().sum()
# Out:
# VUID           0
# Voter          0
# City State     0
# Return Date    0
# dtype: int64

# %%
import pandas as pd
northgate = pd.read_csv("northgate_early_inperson.csv")

# %%
northgate.head()
# Out:
#    CertificateNumber            VoterName    VoterAddress    VoteDate
# 0            7004160      Anderson, Linda   4728 Cedar Ln  2026-06-03
# 1            7007236       Park, Patricia  3840 Aspen Way  2026-06-04
# 2            7008259        Anderson, Mei    1071 Pine Ct  2026-06-01
# 3            7000076  Hernandez, Patricia   6690 Aspen Ln  06/03/2026
# 4            7009804     Hernandez, James    721 Aspen Ct  2026-06-02

# %%
northgate.describe()
# Out:
#        CertificateNumber
# count       1.230000e+02
# mean        7.005091e+06
# std         2.962892e+03
# min         7.000076e+06
# 25%         7.002546e+06
# 50%         7.005314e+06
# 75%         7.007484e+06
# max         7.009921e+06

# %%
northgate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CertificateNumber  123 non-null    int64
#  1   VoterName          123 non-null    object
#  2   VoterAddress       123 non-null    object
#  3   VoteDate           123 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 4.0+ KB

# %%
northgate["VoteDate"] = pd.to_datetime(northgate["VoteDate"], errors="coerce")
northgate["VoterName"] = northgate["VoterName"].astype("string")
northgate["VoterAddress"] = northgate["VoterAddress"].astype("string")

# %%
northgate["CertificateNumber"] = northgate["CertificateNumber"].astype("string")

# %%
northgate["VoteDate"].dt.month
northgate["VoteDate"].dt.year
northgate.sort_values("VoteDate")
# Out:
#     CertificateNumber        VoterName       VoterAddress   VoteDate
# 39            7008429      Davis, Hana       9418 Elm Way 2026-06-01
# 93            7006602      Brown, Hana    7228 Birch Blvd 2026-06-01
# 51            7009491     Brown, James      5357 Cedar Ct 2026-06-01
# 87            7006063  Smith, Patricia    308 Hawthorn St 2026-06-01
# 56            7004400    Okafor, James   749 Dogwood Blvd 2026-06-01
# ..                ...              ...                ...        ...
# 108           7004599      Cohen, Kofi        9955 Oak St        NaT
# 113           7007172    Nguyen, Aisha       2063 Pine Ct        NaT
# 115           7008718     Thomas, Omar  1276 Sycamore Way        NaT
# 119           7006705    Thomas, Aisha   6880 Cypress Way        NaT
# 120           7008242       Ali, Linda      976 Aspen Trl        NaT
#
# [123 rows x 4 columns]

# %%
northgate["VoterAddress"] = northgate["VoterAddress"].astype("category")

# %%
northgate.head()
# Out:
#   CertificateNumber            VoterName    VoterAddress   VoteDate
# 0           7004160      Anderson, Linda   4728 Cedar Ln 2026-06-03
# 1           7007236       Park, Patricia  3840 Aspen Way 2026-06-04
# 2           7008259        Anderson, Mei    1071 Pine Ct 2026-06-01
# 3           7000076  Hernandez, Patricia   6690 Aspen Ln        NaT
# 4           7009804     Hernandez, James    721 Aspen Ct 2026-06-02

# %%
northgate.duplicated().sum()
# Out:
# np.int64(0)

# %%
northgate.isnull().sum()
# Out:
# CertificateNumber     0
# VoterName             0
# VoterAddress          0
# VoteDate             26
# dtype: int64

# %%
import pandas as pd

northgate["VoteDate"] = pd.to_datetime(
    northgate["VoteDate"],
    errors="coerce")

# %%
northgate.isnull().sum()
# Out:
# CertificateNumber     0
# VoterName             0
# VoterAddress          0
# VoteDate             26
# dtype: int64

# %%
northgate[northgate["VoteDate"].isna()]
# Out:
#     CertificateNumber            VoterName       VoterAddress VoteDate
# 3             7000076  Hernandez, Patricia      6690 Aspen Ln      NaT
# 6             7002140         Cohen, Linda       100 Birch Ln      NaT
# 7             7001632        Smith, Carlos     8493 Willow Dr      NaT
# 9             7009827         Brown, Maria  7730 Magnolia Trl      NaT
# 13            7009836        Park, Michael        172 Oak Trl      NaT
# 18            7000130          Smith, Omar    768 Magnolia Ln      NaT
# 26            7000184  Hernandez, Patricia    5343 Cypress St      NaT
# 28            7009921        Thomas, Maria  3003 Juniper Blvd      NaT
# 29            7005314           Brown, Ama     3817 Willow Ct      NaT
# 31            7001224       Anderson, Kofi    5476 Juniper Ln      NaT
# 32            7008394        Johnson, Liam        1614 Elm Ct      NaT
# 44            7006400        Smith, Robert   5539 Sycamore Ln      NaT
# ...

# %%
northgate = northgate.dropna(subset=["VoteDate"])

# %%
northgate.isnull().sum()
# Out:
# CertificateNumber    0
# VoterName            0
# VoterAddress         0
# VoteDate             0
# dtype: int64

# %%
northgate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 0 to 122
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CertificateNumber  97 non-null     string
#  1   VoterName          97 non-null     string
#  2   VoterAddress       97 non-null     category
#  3   VoteDate           97 non-null     datetime64[ns]
# dtypes: category(1), datetime64[ns](1), string(2)
# memory usage: 8.2 KB

# %%
northgate["Month"] = northgate["VoteDate"].dt.month
northgate["Year"] = northgate["VoteDate"].dt.year
northgate["Day"] = northgate["VoteDate"].dt.day

# %%
northgate.head()
# Out:
#   CertificateNumber         VoterName      VoterAddress   VoteDate  Month  \
# 0           7004160   Anderson, Linda     4728 Cedar Ln 2026-06-03      6
# 1           7007236    Park, Patricia    3840 Aspen Way 2026-06-04      6
# 2           7008259     Anderson, Mei      1071 Pine Ct 2026-06-01      6
# 4           7009804  Hernandez, James      721 Aspen Ct 2026-06-02      6
# 5           7002643   Singh, Patricia  4862 Dogwood Way 2026-06-02      6
#
#    Year  Day
# 0  2026    3
# 1  2026    4
# 2  2026    1
# 4  2026    2
# 5  2026    2

# %%
import pandas as pd

registered = pd.read_csv("registered_voters.csv")

# %%
registered.head()
# Out:
#    SOS_VoterID firstname lastname  streetnumber  streetname          address  \
# 0      7005758      Emma   Okafor          4545  Juniper St  4545 Juniper St
# 1      7003258      Yuki   Nguyen          7348  Dogwood Dr  7348 Dogwood Dr
# 2      7007413     Priya   Wilson          4387  Cypress Dr  4387 Cypress Dr
# 3      7006220  Jennifer    Davis          7152  Cypress Dr  7152 Cypress Dr
# 4      7009799     David      Ali          5091  Juniper St  5091 Juniper St
#
#        city      county  precinct_raw        party sex   age  \
# 0  Lakeside  Southfield            15          DEM   M  55.0
# 1  LAKESIDE   Northgate            10          NPA   M  35.0
# 2  LAKESIDE   Northgate            20            U   F  24.0
# 3  LAKESIDE  Southfield            15          LIB   M  29.0
# 4  LAKESIDE   Northgate           110  Independent   M  32.0
#
#               subdivision
# 0                     NaN
# 1  STONEBRIAR SEC 7 (CPL)
# 2    STONEBRIAR SECTION 4
# ...

# %%
registered.describe()
# Out:
#         SOS_VoterID  streetnumber  precinct_raw          age
# count  4.012000e+03   4012.000000   4012.000000  3871.000000
# mean   7.004970e+06   5030.946411     84.371635    54.734694
# std    2.865438e+03   2857.758045     83.216507    23.186685
# min    7.000002e+06    100.000000     10.000000     0.000000
# 25%    7.002492e+06   2526.250000     20.000000    35.000000
# 50%    7.004954e+06   5089.000000     45.000000    54.000000
# 75%    7.007436e+06   7418.750000    130.000000    74.000000
# max    7.009966e+06   9998.000000    264.000000   150.000000

# %%
registered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4012 entries, 0 to 4011
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SOS_VoterID   4012 non-null   int64
#  1   firstname     4012 non-null   object
#  2   lastname      4012 non-null   object
#  3   streetnumber  4012 non-null   int64
#  4   streetname    4012 non-null   object
#  5   address       4012 non-null   object
#  6   city          4012 non-null   object
#  7   county        4012 non-null   object
#  8   precinct_raw  4012 non-null   int64
#  9   party         3715 non-null   object
#  10  sex           3351 non-null   object
#  11  age           3871 non-null   float64
#  12  subdivision   3211 non-null   object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 407.6+ KB

# %%
registered.isnull().sum()
# Out:
# SOS_VoterID       0
# firstname         0
# lastname          0
# streetnumber      0
# streetname        0
# address           0
# city              0
# county            0
# precinct_raw      0
# party           297
# sex             661
# age             141
# subdivision     801
# dtype: int64

# %%
registered['party'] = registered['party'].fillna('Unknown')
registered['sex'] = registered['sex'].fillna('Unknown')
registered['subdivision'] = registered['subdivision'].fillna('Unknown')

# %%
registered['age'] = registered['age'].fillna(registered['age'].median())

# %%
registered['age'] = registered['age'].astype(int)

# %%
cat_cols = ['city', 'county', 'party', 'sex', 'subdivision']

for col in cat_cols:
    registered[col] = registered[col].astype('category')

# %%
registered['sex'] = registered['sex'].str.upper()

# %%
registered['sex'] = registered['sex'].replace({
    'MALE': 'M',
    'FEMALE': 'F'
})

# %%
import pandas as pd

registered = pd.read_csv("registered_voters.csv")

# %%
print(registered.columns)
# Out:
# Index(['SOS_VoterID', 'firstname', 'lastname', 'streetnumber', 'streetname',
#        'address', 'city', 'county', 'precinct_raw', 'party', 'sex', 'age',
#        'subdivision'],
#       dtype='object')

# %%
registered['address'] = (
    registered['streetnumber'].astype(str) + " " +
    registered['streetname'] + ", " +
    registered['city'])

# %%
registered = registered.drop(['streetnumber', 'streetname'], axis=1)

# %%
registered = registered.drop_duplicates()

# %%
registered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 0 to 4011
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SOS_VoterID   4000 non-null   int64
#  1   firstname     4000 non-null   object
#  2   lastname      4000 non-null   object
#  3   address       4000 non-null   object
#  4   city          4000 non-null   category
#  5   county        4000 non-null   category
#  6   precinct_raw  4000 non-null   int64
#  7   party         4000 non-null   category
#  8   sex           4000 non-null   object
#  9   age           4000 non-null   int64
#  10  subdivision   4000 non-null   category
# dtypes: category(4), int64(3), object(4)
# memory usage: 267.1+ KB

# %%
registered.head()
# Out:
#    SOS_VoterID firstname lastname          address      city      county  \
# 0      7005758      Emma   Okafor  4545 Juniper St  Lakeside  Southfield
# 1      7003258      Yuki   Nguyen  7348 Dogwood Dr  LAKESIDE   Northgate
# 2      7007413     Priya   Wilson  4387 Cypress Dr  LAKESIDE   Northgate
# 3      7006220  Jennifer    Davis  7152 Cypress Dr  LAKESIDE  Southfield
# 4      7009799     David      Ali  5091 Juniper St  LAKESIDE   Northgate
#
#    precinct_raw        party sex  age             subdivision
# 0            15          DEM   M   55                 Unknown
# 1            10          NPA   M   35  STONEBRIAR SEC 7 (CPL)
# 2            20            U   F   24    STONEBRIAR SECTION 4
# 3            15          LIB   M   29       OAK HOLLOW UNIT 5
# 4           110  Independent   M   32       WILLOW CREEK PH 3

# %%
import pandas as pd
southfield = pd.read_excel("southfield_early_inperson.xlsx")

# %%
southfield.head()
# Out:
#   Total records: 97       Unnamed: 1 Unnamed: 2  Unnamed: 3
# 0        voter_guid             name       Muni  date_voted
# 1           7003136        Wei Brown   LAKESIDE  2026-06-03
# 2           7002115  Michael Johnson   LAKESIDE  2026-06-03
# 3           7007748   Emma Hernandez   LAKESIDE  2026-06-02
# 4           7003143     Carlos Singh   LAKESIDE  2026-06-01

# %%
southfield.describe()
# Out:
#        Total records: 97  Unnamed: 1 Unnamed: 2  Unnamed: 3
# count                 98          98         98          98
# unique                98          92          2           5
# top           voter_guid  Aisha Khan   LAKESIDE  2026-06-04
# freq                   1           2         97          28

# %%
southfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Total records: 97  98 non-null     object
#  1   Unnamed: 1         98 non-null     object
#  2   Unnamed: 2         98 non-null     object
#  3   Unnamed: 3         98 non-null     object
# dtypes: object(4)
# memory usage: 3.2+ KB

# %%
southfield.columns = southfield.iloc[0]
southfield = southfield[1:]

# %%
southfield = southfield.reset_index(drop=True)

# %%
southfield['voter_guid'] = pd.to_numeric(southfield['voter_guid'], errors='coerce')

# %%
southfield['date_voted'] = pd.to_datetime(southfield['date_voted'], errors='coerce')

# %%
southfield['Muni'] = southfield['Muni'].astype('category')

# %%
southfield = southfield.drop_duplicates()

# %%
southfield.head()
# Out:
# 0  voter_guid                name      Muni date_voted
# 0     7003136           Wei Brown  LAKESIDE 2026-06-03
# 1     7002115     Michael Johnson  LAKESIDE 2026-06-03
# 2     7007748      Emma Hernandez  LAKESIDE 2026-06-02
# 3     7003143        Carlos Singh  LAKESIDE 2026-06-01
# 4     7000080  Patricia Rodriguez  LAKESIDE 2026-06-04

# %%
southfield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   voter_guid  97 non-null     int64
#  1   name        97 non-null     object
#  2   Muni        97 non-null     category
#  3   date_voted  97 non-null     datetime64[ns]
# dtypes: category(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 2.6+ KB

# %%
southfield.isnull().sum()
# Out:
# 0
# voter_guid    0
# name          0
# Muni          0
# date_voted    0
# dtype: int64

# %%
for name, df in {
    "registered": registered,
    "northgate": northgate,
    "southfield": southfield,
    "mail": mail,
    "first_round": first_round
}.items():
    print(f"\n{name.upper()}")
    print(df.head())
    print(df.columns)
    print(df.info())
# Out:
# REGISTERED
#    SOS_VoterID firstname lastname          address      city      county  \
# 0      7005758      Emma   Okafor  4545 Juniper St  Lakeside  Southfield
# 1      7003258      Yuki   Nguyen  7348 Dogwood Dr  LAKESIDE   Northgate
# 2      7007413     Priya   Wilson  4387 Cypress Dr  LAKESIDE   Northgate
# 3      7006220  Jennifer    Davis  7152 Cypress Dr  LAKESIDE  Southfield
# 4      7009799     David      Ali  5091 Juniper St  LAKESIDE   Northgate
#
#    precinct_raw        party sex  age             subdivision
# 0            15          DEM   M   55                 Unknown
# 1            10          NPA   M   35  STONEBRIAR SEC 7 (CPL)
# 2            20            U   F   24    STONEBRIAR SECTION 4
# 3            15          LIB   M   29       OAK HOLLOW UNIT 5
# 4           110  Independent   M   32       WILLOW CREEK PH 3
# Index(['SOS_VoterID', 'firstname', 'lastname', 'address', 'city', 'county',
#        'precinct_raw', 'party', 'sex', 'age', 'subdivision'],
# ...

# %%
southfield = southfield.rename(columns={
    "vote_guid": "certificateNumber",
    "date_voted": "vote_date"})

# %%
print(northgate.columns.tolist())
print(southfield.columns.tolist())
print(registered.columns.tolist())
# Out:
# ['CertificateNumber', 'VoterName', 'VoterAddress', 'VoteDate', 'Month', 'Year', 'Day']
# ['voter_guid', 'name', 'Muni', 'vote_date']
# ['SOS_VoterID', 'firstname', 'lastname', 'address', 'city', 'county', 'precinct_raw', 'party', 'sex', 'age', 'subdivision']

# %%
northgate = northgate.rename(columns={"CertificateNumber": "CertificateNumber"})

# %%
northgate["CertificateNumber"] = northgate["CertificateNumber"].astype(str)
southfield["voter_guid"] = southfield["voter_guid"].astype(str)
registered["SOS_VoterID"] = registered["SOS_VoterID"].astype(str)

# %%
northgate = northgate.drop_duplicates(subset="CertificateNumber")
southfield = southfield.drop_duplicates(subset="voter_guid")

# %%
northgate = northgate.rename(columns={"CertificateNumber": "voter_id"})
southfield = southfield.rename(columns={"voter_guid": "voter_id"})
registered = registered.rename(columns={"SOS_VoterID": "voter_id"})

# %%
northgate["voter_id"] = northgate["voter_id"].astype(str)
southfield["voter_id"] = southfield["voter_id"].astype(str)
registered["voter_id"] = registered["voter_id"].astype(str)

# %%
early_votes = pd.concat(
    [northgate, southfield],
    ignore_index=True
)

early_votes = early_votes.drop_duplicates(subset="voter_id")

# %%
mail = pd.read_excel("mail_ballots.xlsx")

# %%
mail["VUID"] = mail["VUID"].astype(str)

accepted_mail = mail.copy()

# %%
northgate = pd.read_csv("northgate_early_inperson.csv")

# %%
southfield = pd.read_excel("southfield_early_inperson.xlsx")

# %%
# Out:
#   Cell In[3], line 1
#     print(mail.columns.tolist()
#                                ^
# _IncompleteInputError: incomplete input

# %%
mail_voters = set(accepted_mail["VUID"])

northgate_voters = set(northgate["CertificateNumber"].astype(str))
southfield_voters = set(southfield["voter guid"].astype(str))

runoff_voters = mail_voters | northgate_voters | southfield_voters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mail_voters = set(accepted_mail["VUID"])
#       3 northgate_voters = set(northgate["CertificateNumber"].astype(str))
#       4 southfield_voters = set(southfield["voter guid"].astype(str))
#
# NameError: name 'accepted_mail' is not defined

# %%
print("Mail Voters:", mail["VUID"].nunique())
print("Total mail records:", len(mail))
# Out:
# Mail Voters: 69
# Total mail records: 74

# %%
print(northgate.columns.tolist())
print(southfield.columns.tolist())
print(registered.columns.tolist())
# Out:
# ['CertificateNumber', 'VoterName', 'VoterAddress', 'VoteDate']
# ['Total records: 97', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']
# ['SOS_VoterID', 'firstname', 'lastname', 'streetnumber', 'streetname', 'address', 'city', 'county', 'precinct_raw', 'party', 'sex', 'age', 'subdivision']

# %%
import pandas as pd

northgate = pd.read_csv("northgate_early_inperson.csv")
southfield = pd.read_csv("southfield_early_inperson.xlxs")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 4
#       1 import pandas as pd
#       3 northgate = pd.read_csv("northgate_early_inperson.csv")
# ----> 4 southfield = pd.read_csv("southfield_early_inperson.xlxs")
#
# ...

# %%
print(northgate.columns.tolist())
print(southfield.columns.tolist())
# Out:
# ['CertificateNumber', 'VoterName', 'VoterAddress', 'VoteDate']
# ['Total records: 97', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']

# %%
northgate = northgate.rename(columns={'CertificateNumber': 'voter_id'})
southfield = southfield.rename(columns={'voter_guid': 'voter_id'})

early_votes = pd.concat([
    northgate[['voter_id']],
    southfield[['voter_id']]
], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 6
#       1 northgate = northgate.rename(columns={'CertificateNumber': 'voter_id'})
#       2 southfield = southfield.rename(columns={'voter_guid': 'voter_id'})
#       4 early_votes = pd.concat([
#       5     northgate[['voter_id']],
# ----> 6     southfield[['voter_id']]
#       7 ], ignore_index=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %%
print(southfield.columns.tolist())
# Out:
# ['Total records: 97', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']

# %%
registered_voters = registered_voters.merge(
    registered,
    left_on="voter_id",
    right_on="SOS_VoterID",
    how="inner")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 registered_voters = registered_voters.merge(
#       2     registered,
#       3     left_on="voter_id",
#       4     right_on="SOS_VoterID",
#       5     how="inner")
#
# NameError: name 'registered_voters' is not defined
